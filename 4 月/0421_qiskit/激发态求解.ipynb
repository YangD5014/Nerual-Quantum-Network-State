# %%
from qiskit_nature.units import DistanceUnit
from qiskit_nature.second_q.drivers import PySCFDriver
from qiskit_nature.second_q.mappers import JordanWignerMapper
from qiskit_algorithms import NumPyEigensolver



driver = PySCFDriver(
    atom="H 0 0 0; H 0 0 1.4",
    basis="sto3g",
    charge=0,
    spin=0,
    unit=DistanceUnit.ANGSTROM,
)

es_problem = driver.run()
mapper = JordanWignerMapper()
numpy_solver = NumPyEigensolver(k=4, filter_criterion=es_problem.get_default_filter_criterion())

# %%
from qiskit_algorithms import VQE
from qiskit_algorithms.optimizers import SLSQP
#from qiskit.primitives import Estimator
from qiskit_nature.second_q.algorithms import GroundStateEigensolver
from qiskit_nature.second_q.circuit.library import HartreeFock, UCCSD
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[5], line 4
#       2 from qiskit_algorithms.optimizers import SLSQP
#       3 #from qiskit.primitives import Estimator
# ----> 4 from qiskit_nature.second_q.algorithms import GroundStateEigensolver
#       5 from qiskit_nature.second_q.circuit.library import HartreeFock, UCCSD
#
# File /opt/miniconda3/envs/DeepQMC/lib/python3.10/site-packages/qiskit_nature/second_q/algorithms/__init__.py:96
#       1 # This code is part of a Qiskit project.
#       2 #
#       3 # (C) Copyright IBM 2019, 2023.
#    (...)
#      10 # copyright notice, and modified files need to carry a notice indicating
#      11 # that they have been altered from the originals.
#      13 """
#      14 Algorithms (:mod:`qiskit_nature.second_q.algorithms`)
#      15 =====================================================
#    (...)
#      93    initial_points
#      94 """
# ---> 96 from .excited_states_solvers import (
#      97     ExcitedStatesEigensolver,
#      98     ExcitedStatesSolver,
#      99     QEOM,
#     100     QEOMResult,
#     101     EvaluationRule,
#     102 )
#     103 from .ground_state_solvers import (
#     104     GroundStateEigensolver,
#     105     GroundStateSolver,
#     106 )
#     108 __all__ = [
#     109     "ExcitedStatesEigensolver",
#     110     "ExcitedStatesSolver",
#    (...)
#     115     "GroundStateSolver",
#     116 ]
#
# File /opt/miniconda3/envs/DeepQMC/lib/python3.10/site-packages/qiskit_nature/second_q/algorithms/excited_states_solvers/__init__.py:22
#      13 """
#      14 Excited State Solving Algorithms (:mod:`qiskit_nature.second_q.algorithms.excited_states_solvers`)
#      15 ==================================================================================================
#    (...)
#      18
#      19 """
#      21 from .excited_states_solver import ExcitedStatesSolver
# ---> 22 from .qeom import QEOM, QEOMResult, EvaluationRule
#      23 from .excited_states_eigensolver import ExcitedStatesEigensolver
#      25 __all__ = [
#      26     "ExcitedStatesSolver",
#      27     "ExcitedStatesEigensolver",
#    (...)
#      30     "EvaluationRule",
#      31 ]
#
# File /opt/miniconda3/envs/DeepQMC/lib/python3.10/site-packages/qiskit_nature/second_q/algorithms/excited_states_solvers/qeom.py:31
#      29 from qiskit.circuit import QuantumCircuit
#      30 from qiskit.quantum_info import SparsePauliOp
# ---> 31 from qiskit.primitives import BaseEstimator
#      33 from qiskit_nature.second_q.algorithms.ground_state_solvers import GroundStateSolver
#      34 from qiskit_nature.second_q.algorithms.excited_states_solvers.excited_states_solver import (
#      35     ExcitedStatesSolver,
#      36 )
#
# ImportError: cannot import name 'BaseEstimator' from 'qiskit.primitives' (/opt/miniconda3/envs/DeepQMC/lib/python3.10/site-packages/qiskit/primitives/__init__.py)
