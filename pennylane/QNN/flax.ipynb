# %%
from flax import nnx
import jax
import jax.numpy as jnp

# %%
nnx.Param(jnp.zeros((2)))
# Out:
# Param( # 2 (8 B)
#   value=Array([0., 0.], dtype=float32)
# )

# %%
jnp.zeros((2))
# Out:
# Array([0., 0.], dtype=float32)
