# %%
from h4_vmc import run_h4_vmc

result = run_h4_vmc(bond_distance=0.74)
print(result['energy_mean'])  # 获取能量均值数组
print(result['final_vmc_energy'])  # 获取最终能量
# Out:
# 100%|██████████| 300/300 [00:11<00:00, 26.69it/s, Energy=-2.10395+0.00008j ± 0.00041 [σ²=0.00009, R̂=1.0146]]
# ...
